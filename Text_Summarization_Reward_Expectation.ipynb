# %%
# Import the machine learning libraries.
import bs4 as bs
import urllib.request
import re
import nltk
import matplotlib.pyplot as plt
from wordcloud import WordCloud
nltk.download('stopwords')
nltk.download('punkt')
import heapq
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Install BeautifulSoup 4.
# !pip install beautifulsoup4

# %%
# Install lxml.
# !pip install lxml

# %%
# Get the data source from the Wikipedia.
source = urllib.request.urlopen('https://www.eneuro.org/content/6/3/ENEURO.0178-19.2019').read()

# %%
# Parse the data and create BeautifulSoup object.
soup = bs.BeautifulSoup(source,'lxml')

# %%
#soup.prettify()

# %%
# Fetch the data.
text = ""
for paragraph in soup.find_all('p'):
    text += paragraph.text

# %%
#print(text)

# %%
# Preprocess the data.
text = re.sub(r'\[[0-9]*\]',' ',text)
text = re.sub(r'\s+',' ',text)
clean_text = text.lower()
clean_text = re.sub(r'\W',' ',clean_text)
clean_text = re.sub(r'\d',' ',clean_text)
clean_text = re.sub(r'\s+',' ',clean_text)

# Remove specific words.
clean_text = clean_text.replace("et al ","")
clean_text = clean_text.replace("fig ","")
clean_text = clean_text.replace("upper row ","")
clean_text = clean_text.replace("bottom row ","")
clean_text = clean_text.replace("row ","")
clean_text = clean_text.replace("subplot ","")
clean_text = clean_text.replace("left column ","")
clean_text = clean_text.replace("right column ","")

# %%
#print(clean_text)

# %%
# Word cloud for the cleaned text.
plt.figure(figsize=(20,10))
WC = WordCloud(width=1000, height=500, max_words=500, min_font_size=5)
wc_clean_text = WC.generate(clean_text)
plt.imshow(wc_clean_text, interpolation='bilinear')
plt.title('Words', fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Tokenize sentences.
sentences = nltk.sent_tokenize(text)

# %%
#print(sentences)

# %%
# Stopword list.
stop_words = nltk.corpus.stopwords.words('english')

# %%
# Word counts.
word2count = {}
for word in nltk.word_tokenize(clean_text):
    if word not in stop_words:
        if word not in word2count.keys():
            word2count[word] = 1
        else:
            word2count[word] += 1

# %%
# Convert counts to weights.
max_count = max(word2count.values())
for key in word2count.keys():
    word2count[key] = word2count[key]/max_count

# %%
# Product sentence scores.
sent2score = {}
for sentence in sentences:
    for word in nltk.word_tokenize(sentence.lower()):
        if word in word2count.keys():
            if len(sentence.split(' ')) < 25:
                if sentence not in sent2score.keys():
                    sent2score[sentence] = word2count[word]
                else:
                    sent2score[sentence] += word2count[word]

# %%
# Get the optimal 3 lines.
n_sentences = 3
best_sentences = heapq.nlargest(n_sentences, sent2score, key=sent2score.get)

# %%
# Print 3 sentences.
for sentence in best_sentences:
    print(sentence, sep = "\n")
# Out:
# The number of significant M1 units of NHP P’s neural spiking rate during observational tasks was lower compared with significance of manual tasks.
# There was one exception for NHP A during observational tasks where trials followed a set structure or rewarding followed by nonrewarding and repeating.
# During manual and observational tasks, rewarding and nonrewarding trials were presented in a random order.
